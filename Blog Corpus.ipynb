# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import re
from google.oauth2 import service_account
from googleapiclient.discovery import build
import io
from googleapiclient.http import MediaIoBaseDownload
import xml.etree.ElementTree as ET
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
folder_path = '/content/drive/MyDrive/Data Mining Project/blogs'

pattern = re.compile(r'(\d+)\.(\w+)\.(\d+)\.(\w+)\.(\w+)')

data = []
unicode_errors_list = []
parsing_errors_list = []

def replace_ampersand(text):
    # Replace & with &amp; if it's not already in the &amp; format
    return re.sub(r'&(?!amp;)', '&amp;', text)

file_list = [file for file in os.listdir(folder_path) if re.match(pattern, file)]

for file_name in tqdm(file_list, desc="Processing XML files"):

  match = re.match(pattern, file_name)

  try:
    number, gender, age, genre, zodiac = match.groups()
    xml_file_path = os.path.join(folder_path, file_name)
    with open(xml_file_path, 'r', encoding='utf-8') as file:
      xml_content = file.read()

    # Replace & with &amp; where necessary
    modified_xml_content = replace_ampersand(xml_content)
    tree = ET.ElementTree(ET.fromstring(modified_xml_content))
    root = tree.getroot()

    dates = [date.text for date in root.findall(".//date")]
    posts = [post.text for post in root.findall(".//post")]


    for date, post in zip(dates, posts):
        data.append({
          "Number": number,
          "Gender": gender,
          "Age": age,
          "Post Genre": genre,
          "Zodiac Sign": zodiac,
          "Date": date,
          "Post": post
        })

  except ET.ParseError:
      parsing_errors_list.append(xml_file_path)
      continue
  except UnicodeDecodeError as decode_error:
      unicode_errors_list.append(xml_file_path)
      continue
# Out:
# Processing XML files: 100%|██████████| 18266/18266 [08:52<00:00, 34.32it/s]

# %%
len(parsing_errors_list)
# Out:
# 300

# %%
len(unicode_errors_list)
# Out:
# 563

# %%
folder_path = '/content/drive/MyDrive/Data Mining Project/blogs'

pattern = re.compile(r'(\d+)\.(\w+)\.(\d+)\.(\w+)\.(\w+)')

data = []


def replace_ampersand(text):
    # Replace & with &amp; if it's not already in the &amp; format
    return re.sub(r'&(?!amp;)', '&amp;', text)

file_list = [file for file in os.listdir(folder_path) if re.match(pattern, file)]

for file_name in tqdm(file_list, desc="Processing XML files"):

  match = re.match(pattern, file_name)

  try:
    number, gender, age, genre, zodiac = match.groups()
    xml_file_path = os.path.join(folder_path, file_name)
    with open(xml_file_path, 'r', encoding='utf-32') as file:
         xml_content = file.read()

    # Replace & with &amp; where necessary
    modified_xml_content = replace_ampersand(xml_content)

    tree = ET.ElementTree(ET.fromstring(modified_xml_content))
    root = tree.getroot()

    dates = [date.text for date in root.findall(".//date")]
    posts = [post.text for post in root.findall(".//post")]


    for date, post in zip(dates, posts):
        data.append({
          "Number": number,
          "Gender": gender,
          "Age": age,
          "Post Genre": genre,
          "Zodiac Sign": zodiac,
          "Date": date,
          "Post": post
        })

  except ET.ParseError:
      print(f"Error parsing XML file: {xml_file_path}")
      continue

# %%
file_list[521]
# Out:
# '4286996.female.14.indUnk.Libra.xml'

# %%
parsing_errors_list
# Out:
# ['/content/drive/MyDrive/Data Mining Project/blogs/4299910.male.17.Student.Cancer.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/4300864.female.26.Religion.Sagittarius.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/4307329.female.16.Student.Libra.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/4312209.female.16.indUnk.Virgo.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/4177529.male.16.Student.Aries.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/4180104.male.16.indUnk.Scorpio.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs
xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3312717.male.16.Student.Virgo.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2425281.male.14.Student.Capricorn.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/1392111.female.34.indUnk.Leo.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2033501.male.17.indUnk.Cancer.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3032139.female.26.Arts.Taurus.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2046767.female.16.indUnk.Aquarius.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/1063313.female.16.Student.Libra.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3051503.male.27.Technology.Libra.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/1070540.female.36.Technology.Scorpio.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3061874.male.25.Technology.Pisces.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/1084668.female.15.Student.Capricorn.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/1089670.female.17.Student.Sagittarius.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3071102.female.33.Technology.Cancer.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2087401.male.16.Student.Pisces.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3076129.female.15.indUnk.Gemini.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3077147.female.17.indUnk.Pisces.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3087742.male.15.indUnk.Capricorn.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3091107.male.23.Engineering.Leo.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3093428.female.17.Student.Taurus.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3096879.male.23.Marketing.Scorpio.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2134154.male.16.Arts.Taurus.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3112880.male.13.Student.Libra.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2147592.female.15.Student.Aquarius.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2151828.male.17.indUnk.Gemini.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3128727.male.23.indUnk.Scorpio.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2161435.male.16.Student.Virgo.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2163386.male.26.Government.Taurus.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3139191.male.16.indUnk.Aquarius.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/1169202.male.26.Science.Libra.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3158527.female.15.indUnk.Taurus.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3169212.female.15.Student.Cancer.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2209219.female.27.indUnk.Cancer.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2227332.female.16.indUnk.Capricorn.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3196262.male.13.indUnk.Virgo.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3808793.female.13.Student.Taurus.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3809161.female.14.indUnk.Leo.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3813297.female.13.Student.Capricorn.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3006822.male.39.Technology.Cancer.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/2017951.male.26.indUnk.Libra.xml',
#  '/content/drive/MyDrive/Data Mining Project/blogs/3016212.female.35.indUnk.Aries.xml']

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#          Number  Gender Age          Post Genre Zodiac Sign            Date  \
# 0       4244359  female  38              indUnk       Libra  21,August,2004
# 1       4244359  female  38              indUnk       Libra  16,August,2004
# 2       4244359  female  38              indUnk       Libra  16,August,2004
# 3       4244359  female  38              indUnk       Libra  16,August,2004
# 4       4244468    male  14              indUnk       Libra  16,August,2004
# ...         ...     ...  ..                 ...         ...             ...
# 453872  3019173  female  23  Telecommunications   Capricorn     07,May,2004
# 453873  3019173  female  23  Telecommunications   Capricorn    17,June,2004
# 453874  3019173  female  23  Telecommunications   Capricorn    08,June,2004
# 453875  3019173  female  23  Telecommunications   Capricorn    28,July,2004
# 453876  3019173  female  23  Telecommunications   Capricorn  05,August,2004
#
#                                                      Post
# 0       \n\n     \n      I didn't sleep much at all la...
# 1       \n\n     \n      I watched Oprah the other day...
# 2       \n\n     \n      I often wonder if life is not...
# 3       \n\n     \n       I'm not quite sure what poss...
# 4       \n\n\t \n      This is probably gona be the la...
# ...                                                   ...
# 453872  \n\n\t\t\t\t\t\t\n\t\t\t\t\t\t   I had my weig...
# 453873  \n\n\t\t\t\t\t\t\n\t\t\t\t\t\t   Life has a wa...
# 453874  \n\n\t\t\t\t\t\t\n\t\t\t\t\t\t   Good morning ...
# 453875  \n\n\t\t\t\t\t\t\n\t\t\t\t\t\t   My pain is al...
# 453876  \n\n\t\t\t\t\t\t\n\t\t\t\t\t\t   After days, a...
#
# [453877 rows x 7 columns]

# %%
for root, dirs, files in os.walk(folder_path):
    for file_name in files:
        print(file_name)
